# %% [markdown]
# # data.world
# ## Infectious Disease 2001-2014

# %% [markdown]
# > #### Setup
#
# > Before running data.world notebooks for the first time, you'll need to:
# 1. Install data.world's Python package, including optional `pandas` dependencies:
# ```shell
# pip install git+git://github.com/datadotworld/data.world-py.git#egg=project[pandas]
# ```
# 1. Obtain an API access token at https://data.world/settings/advanced
# 1. Store API access token using the `dw` command-line tool:
# ```shell
# dw configure
# ```
#
# > Once your environment is set up, these steps do not need to be repeated for other data.world notebooks.

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# use the 'seaborn-colorblind' style
plt.style.use('seaborn-colorblind')
import seaborn as sns
import pandas as pd

# %%
import datadotworld as dw

# %%
# Datasets are referenced by their path
dataset_key = 'health/infectious-disease-2001-2014'

# Or simply by their URL
dataset_key = 'https://data.world/health/infectious-disease-2001-2014'

# %%
# Load dataset (onto the local file system)
dataset_local = dw.load_dataset(dataset_key)  # cached under ~/.dw/cache

# %%
# See what is in it
dataset_local.describe()
# Out:
# {'description': 'Infectious Disease Cases by County, Year, and Sex, 2001-2014\n\nThese data contain counts and rates for Centers for Infectious Diseases-related disease cases among California residents by county, disease, sex, and year spanning 2001-2014 (As of September, 2015). \n\nAttribution: [HealthData.gov](http://www.healthdata.gov/dataset/infectious-disease-cases-county-year-and-sex-2001-2014) and [CHHS Open Data](http://www.healthdata.gov/dataset/infectious-disease-cases-county-year-and-sex-2001-2014).',
#  'homepage': 'https://data.world/health/infectious-disease-2001-2014',
#  'keywords': ['health', 'disease', 'california'],
#  'license': 'ODC-ODbL',
#  'name': 'health_infectious-disease-2001-2014',
#  'resources': [{'format': 'csv',
#    'name': 'counties',
#    'path': 'data/counties.csv'},
#   {'format': 'csv',
#    'name': 'data_dictionary',
#    'path': 'data/data_dictionary.csv'},
#   {'format': 'csv',
#    'name': 'diseases_branches',
#    'path': 'data/diseases_branches.csv'},
#   {'format': 'csv', 'name': 'rows', 'path': 'data/rows.csv'},
#   {'bytes': 18037,
#    'format': 'xlsx',
#    'mediatype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#    'name': 'original/CID-Cases-by-Disease-County-Year-Sex-DATA-DICTIONARY.xlsx',
#    'path': 'original/CID-Cases-by-Disease-County-Year-Sex-DATA-DICTIONARY.xlsx'},
#   {'bytes': 19327,
#    'format': 'docx',
#    'mediatype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#    'name': 'original/CID-Cases-by-Disease-County-Year-Sex-NOTES.docx',
#    'path': 'original/CID-Cases-by-Disease-County-Year-Sex-NOTES.docx'},
#   {'bytes': 8731540,
#    'format': 'csv',
#    'mediatype': 'text/csv',
#    'name': 'original/rows.csv',
#    'path': 'original/rows.csv'}],
#  'title': 'Infectious Disease 2001-2014'}

# %% [markdown]
# # Next steps
#
# - Run `help()` to learn more ways to access and use your data. Try:
#   - `help(dw.load_dataset)`
#   - `help(dw.query)`
# - Learn more at: https://github.com/datadotworld/data.world-py and https://docs.data.world

# %%
dataset_local.dataframes
# Out:
# LazyLoadedDict({'counties': LazyLoadedValue(<pandas.DataFrame>), 'data_dictionary': LazyLoadedValue(<pandas.DataFrame>), 'diseases_branches': LazyLoadedValue(<pandas.DataFrame>), 'rows': LazyLoadedValue(<pandas.DataFrame>)})

# %%
for i in dataset_local.dataframes:
    dataset_local.tables[i].to_csv(i+'.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-9298a2adc212> in <module>()
#       1 for i in dataset_local.dataframes:
# ----> 2     dataset_local.tables[i].to_csv(i+'.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
counties_table = dataset_local.tables['counties']

# %%
counties_table
# Out:
# [OrderedDict([('alameda', 'Alpine')]),
#  OrderedDict([('alameda', 'Amador')]),
#  OrderedDict([('alameda', 'Butte')]),
#  OrderedDict([('alameda', 'Calaveras')]),
#  OrderedDict([('alameda', 'Colusa')]),
#  OrderedDict([('alameda', 'Contra Costa')]),
#  OrderedDict([('alameda', 'Del Norte')]),
#  OrderedDict([('alameda', 'El Dorado')]),
#  OrderedDict([('alameda', 'Fresno')]),
#  OrderedDict([('alameda', 'Glenn')]),
#  OrderedDict([('alameda', 'Humboldt')]),
#  OrderedDict([('alameda', 'Imperial')]),
#  OrderedDict([('alameda', 'Inyo')]),
#  OrderedDict([('alameda', 'Kern')]),
#  OrderedDict([('alameda', 'Kings')]),
#  OrderedDict([('alameda', 'Lake')]),
#  OrderedDict([('alameda', 'Lassen')]),
#  OrderedDict([('alameda', 'Los Angeles')]),
#  OrderedDict([('alameda', 'Madera')]),
#  OrderedDict([('alameda', 'Marin')]),
#  OrderedDict([('alameda', 'Mariposa')]),
#  OrderedDict([('alameda', 'Mendocino')]),
#  OrderedDict([('alameda', 'Merced')]),
#  OrderedDict([('alameda', 'Modoc')]),
#  OrderedDict([('alameda', 'Mono')]),
#  OrderedDict([('alameda', 'Monterey')]),
#  OrderedDict([('alameda', 'Napa')]),
#  OrderedDict([('alameda', 'Nevada')]),
#  OrderedDict([('alameda', 'Orange')]),
#  OrderedDict([('alameda', 'Placer')]),
#  OrderedDict([('alameda', 'Plumas')]),
#  OrderedDict([('alameda', 'Riverside')]),
#  OrderedDict([('alameda', 'Sacramento')]),
#  OrderedDict([('alameda', 'San Benito')]),
#  OrderedDict([('alameda', 'San Bernardino')]),
#  OrderedDict([('alameda', 'San Diego')]),
#  OrderedDict([('alameda', 'San Francisco')]),
#  OrderedDict([('alameda', 'San Joaquin')]),
#  OrderedDict([('alameda', 'San Luis Obispo')]),
#  OrderedDict([('alameda', 'San Mateo')]),
#  OrderedDict([('alameda', 'Santa Barbara')]),
#  OrderedDict([('alameda', 'Santa Clara')]),
#  OrderedDict([('alameda', 'Santa Cruz')]),
#  OrderedDict([('alameda', 'Shasta')]),
#  OrderedDict([('alameda', 'Sierra')]),
#  OrderedDict([('alameda', 'Siskiyou')]),
#  OrderedDict([('alameda', 'Solano')]),
#  OrderedDict([('alameda', 'Sonoma')]),
#  OrderedDict([('alameda', 'Stanislaus')]),
#  OrderedDict([('alameda', 'Sutter')]),
#  OrderedDict([('alameda', 'Tehama')]),
#  OrderedDict([('alameda', 'Trinity')]),
#  OrderedDict([('alameda', 'Tulare')]),
#  OrderedDict([('alameda', 'Tuolumne')]),
#  OrderedDict([('alameda', 'Ventura')]),
#  OrderedDict([('alameda', 'Yolo')]),
#  OrderedDict([('alameda', 'Yuba')])]

# %%
diseases_branches_table = dataset_local.tables['diseases_branches']

# %%
diseases_branches_table
# Out:
# [OrderedDict([('disease', 'Amebiasis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Anaplasmosis and Ehrlichiosis'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Babesiosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Botulism, Foodborne'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Botulism, Other'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Botulism, Wound'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Brucellosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Campylobacteriosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Chlamydia'), ('branch_office', 'STD')]),
#  OrderedDict([('disease', 'Cholera'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Ciguatera Fish Poisoning'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Coccidioidomycosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease',
#                'Creutzfeldt-Jakob Disease and other Transmissible Spongiform Encephalopathies'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Cryptosporidiosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Cyclosporiasis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Cysticercosis or Taeniasis'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Dengue'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Diphtheria'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'E. coli O157'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'E. coli Other STEC (non-O157)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Early Syphilis'), ('branch_office', 'STD')]),
#  OrderedDict([('disease', 'Giardiasis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Gonorrhea'), ('branch_office', 'STD')]),
#  OrderedDict([('disease', 'Hantavirus Infection'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Hemolytic Uremic Syndrome'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Hepatitis A'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Hepatitis B, Acute'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Hepatitis C, Acute'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Hepatitis E, acute infection'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'HIV'), ('branch_office', 'OA')]),
#  OrderedDict([('disease', 'Influenza Death (<65 years of age)'),
#               ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Invasive Meningococcal Disease'),
#               ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Legionellosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Leprosy'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Leptospirosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Listeriosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Lyme Disease'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Malaria'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Measles'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Mumps'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Paralytic Shellfish Poisoning'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Pertussis'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Plague, human'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Psittacosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Q Fever'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Rabies, human'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Relapsing Fever'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Rubella'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Salmonellosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Scombroid Fish Poisoning'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease',
#                'Shiga Toxin Positive Feces (without culture confirmation)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Shigellosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Spotted Fever Rickettsiosis'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease',
#                'Staphylococcus aureus Infection (cases resulting in death or ICU)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease',
#                'Streptococcal Infection (cases in food and dairy workers)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Tetanus'), ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Toxic Shock Syndrome (Non-Streptococcal)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Trichinosis'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Tuberculosis'), ('branch_office', 'TBB')]),
#  OrderedDict([('disease', 'Tularemia'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Typhoid Fever, case'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Typhus Fever'), ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Varicella Hospitalizations'),
#               ('branch_office', 'IZB')]),
#  OrderedDict([('disease', 'Vibrio Infection (non-Cholera)'),
#               ('branch_office', 'IDB')]),
#  OrderedDict([('disease', 'Yersiniosis'), ('branch_office', 'IDB')])]

# %%
SQLs = {1: 'select year, disease, count from rows where rows.disease in'
                '("HIV", "Gonorrhea", "Early Syphilis") and year<2014',
        2: 'select year, disease, rate from rows where rows.disease in'
                '("HIV", "Gonorrhea", "Early Syphilis") and year<2014'}

# %%
dw.query(dataset_key, SQLs[1]).dataframe.groupby(['year','disease']).sum().unstack(fill_value=0).plot()

# %%
dw.query(dataset_key, SQLs[1]).dataframe.groupby(['year','disease']).sum().unstack(fill_value=0).plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### So, STIs were ingreasing while HIV dropped year by year.
#
# ### Let's check this hypothesis if rate?

# %%
dw.query(dataset_key, SQLs[2]).dataframe.groupby(['year','disease']).sum().unstack(fill_value=0).plot.box();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
dw.query(dataset_key, SQLs[2]).dataframe.groupby(['year','disease']).sum().unstack(fill_value=0)
# Out:
#                   rate
# disease Early Syphilis  Gonorrhea       HIV
# year
# 2001           215.086   5852.149  1508.959
# 2002           374.821   6335.208  1624.640
# 2003           432.506   7235.213  1374.797
# 2004           470.885   9407.695  1292.919
# 2005           492.302  10628.774  1163.565
# 2006           605.405   9457.864  1341.902
# 2007           608.214   8772.287  1304.482
# 2008           759.861   6252.928  1279.098
# 2009           663.555   6041.380  1208.614
# 2010           746.066   6375.568  1092.283
# 2011           891.532   6851.866  1064.098
# 2012          1143.744   8971.218  1125.371
# 2013          1466.533  11477.887   948.942

# %%
results.dataframe.groupby(['disease']).count()
# Out:
#                     county  year   sex  count  population  rate  ci_lower  \
# disease
# Early Syphilis        2478  2478  2478   2478        2478  2478      2478
# Gonorrhea             2478  2478  2478   2478        2478  2478      2478
# HIV                   2478  2478  2478   2478        2478  2478      2478
# Hepatitis B, Acute     708   708   708    708         708   708       708
# Hepatitis C, Acute     708   708   708    708         708   708       708
#
#                     ci_upper  unstable
# disease
# Early Syphilis          2478       883
# Gonorrhea               2478       784
# HIV                     2478       987
# Hepatitis B, Acute       708       221
# Hepatitis C, Acute       708       210

# %%
pd.tools.plotting.scatter_matrix(iris);

# %%
df1 = pd.read_csv('https://query.data.world/s/32k7h876aprvdxf33i9yponf2')

# %%
df1.to_csv('diseases_26.csv')

# %%
df1.head()
# Out:
#      Disease      County  Year     Sex  Count  Population   Rate  CI.lower  \
# 0  Amebiasis  California  2001   Total    571    34514777  1.654     1.521
# 1  Amebiasis  California  2001  Female    176    17340743  1.015     0.871
# 2  Amebiasis  California  2001    Male    365    17174034  2.125     1.913
# 3  Amebiasis  California  2002   Total    442    34940334  1.265     1.150
# 4  Amebiasis  California  2002  Female    145    17555714  0.826     0.697
#
#    CI.upper Unstable
# 0     1.796
# 1     1.176
# 2     2.355
# 3     1.389
# 4     0.972

# %%
df1[(df1.County == 'Sacramento') & (df1.Disease == 'HIV') & (df1.Year == 2013)].head()
# Out:
#       Disease      County  Year     Sex  Count  Population    Rate  CI.lower  \
# 62655     HIV  Sacramento  2013   Total    168     1445457  11.623     9.932
# 62656     HIV  Sacramento  2013  Female     25      736595   3.394     2.196
# 62657     HIV  Sacramento  2013    Male    143      708862  20.173    17.003
#
#        CI.upper Unstable
# 62655    13.519
# 62656     5.010
# 62657    23.763

# %% [markdown]
# ## Calculating normalized relative changes of rates

# %%
df3 = df1['Disease', 'County', 'Year', 'Rate']

# %%
df1.County.unique()
# Out:
# array(['California', 'Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras',
#        'Colusa', 'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno',
#        'Glenn', 'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake',
#        'Lassen', 'Los Angeles', 'Madera', 'Modoc', 'Marin', 'Mariposa',
#        'Mendocino', 'Merced', 'Mono', 'Monterey', 'Napa', 'Nevada',
#        'Orange', 'Placer', 'Plumas', 'Riverside', 'Sacramento',
#        'San Benito', 'San Bernardino', 'San Diego', 'San Francisco',
#        'San Joaquin', 'San Luis Obispo', 'San Mateo', 'Santa Barbara',
#        'Santa Clara', 'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou',
#        'Solano', 'Sonoma', 'Stanislaus', 'Sutter', 'Tehama', 'Trinity',
#        'Tulare', 'Tuolumne', 'Ventura', 'Yolo', 'Yuba'], dtype=object)

# %%
len(df1.County.unique())
# Out:
# 59

# %%
df1.groupby?

# %%
df1[['Year', 'County', 'Disease', 'Count']].groupby(['County', 'Disease', 'Year']).sum().plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df1[['Year', 'County', 'Disease', 'Count']].groupby(['County', 'Disease', 'Year']).sum().unstack(fill_value=0).T
# Out:
# County       Alameda                                           \
# Disease    Amebiasis Anaplasmosis and Ehrlichiosis Babesiosis
#       Year
# Count 2001        32                             0          0
#       2002        18                             0          0
#       2003        13                             0          0
#       2004        14                             2          0
#       2005        18                             0          0
#       2006        12                             0          0
#       2007        18                             0          0
#       2008        18                             0          2
#       2009        30                             0          2
#       2010        48                             0          0
#       2011        41                             0          2
#       2012        54                             0          0
#       2013        24                             0          0
#       2014        24                             0          0
#
# County                                                                      \
# Disease    Botulism, Foodborne Botulism, Other Botulism, Wound Brucellosis
#       Year
# Count 2001                   0               0               0           2
#       2002                   0               0               2           2
#       2003                   0               0              10           0
#       2004                   0               0               2           2
#       2005                   0               0               2           2
#       2006                   0               0              16           6
#       2007                   0               0               4           6
#       2008                   2               0               2           0
#       2009                   0               0              12           2
#       2010                   0               0               6           0
#       2011                   0               0               2           2
#       2012                   0               0               0           0
#       2013                   0               0               0           0
#       2014                   0               0               4           0
#
# County                                              ...        Yuba  \
# Disease    Campylobacteriosis Chlamydia Cholera     ...     Tetanus
#       Year                                          ...
# Count 2001                513      9678       0     ...           0
#       2002                728      9725       0     ...           0
#       2003                604      9851       0     ...           0
#       2004                622     10491       0     ...           0
#       2005                656     10407       0     ...           0
#       2006                639     12051       0     ...           0
#       2007                732     14170       2     ...           0
#       2008                657     13940       0     ...           0
#       2009                697     13567       0     ...           0
#       2010                718     14057       0     ...           0
#       2011                714     13303       0     ...           0
#       2012                832     13015       0     ...           0
#       2013                815     12912       0     ...           0
#       2014                778     14027       0     ...           0
#
# County                                                                        \
# Disease    Toxic Shock Syndrome (Non-Streptococcal) Trichinosis Tuberculosis
#       Year
# Count 2001                                        0           0            6
#       2002                                        0           0           12
#       2003                                        0           0            6
#       2004                                        0           0           14
#       2005                                        0           0            4
#       2006                                        0           0            0
#       2007                                        0           0           12
#       2008                                        0           0           10
#       2009                                        0           0            0
#       2010                                        0           0            2
#       2011                                        0           0            2
#       2012                                        0           0            4
#       2013                                        0           0           10
#       2014                                        0           0            4
#
# County                                                 \
# Disease    Tularemia Typhoid Fever, case Typhus Fever
#       Year
# Count 2001         0                   0            0
#       2002         0                   0            0
#       2003         0                   0            0
#       2004         0                   0            0
#       2005         0                   0            0
#       2006         0                   0            0
#       2007         0                   0            0
#       2008         0                   0            0
#       2009         0                   0            0
#       2010         0                   0            0
#       2011         0                   0            0
#       2012         0                   0            0
#       2013         0                   0            0
#       2014         0                   0            0
#
# County                                                                \
# Disease    Varicella Hospitalizations Vibrio Infection (non-Cholera)
#       Year
# Count 2001                          0                              0
#       2002                          0                              0
#       2003                          0                              0
#       2004                          0                              2
#       2005                          0                              0
#       2006                          0                              0
#       2007                          0                              0
#       2008                          0                              0
#       2009                          0                              2
#       2010                          0                              0
#       2011                          0                              0
#       2012                          0                              0
#       2013                          0                              0
#       2014                          0                              0
#
# County
# Disease    Yersiniosis
#       Year
# Count 2001           0
#       2002           2
#       2003           0
#       2004           0
#       2005           0
#       2006           0
#       2007           0
#       2008           0
#       2009           0
#       2010           0
#       2011           0
#       2012           0
#       2013           0
#       2014           0
#
# [14 rows x 3835 columns]

# %%
df1[['Year', 'County', 'Disease', 'Count']].groupby(['County', 'Disease', 'Year']).sum().unstack(fill_value=0).T.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Very slow means calculating:

# %%
df_means =

# %%
df1[['Year', 'County', 'Disease', 'Count']]
# Out:
#         Year      County      Disease  Count
# 0       2001  California    Amebiasis    571
# 1       2001  California    Amebiasis    176
# 2       2001  California    Amebiasis    365
# 3       2002  California    Amebiasis    442
# 4       2002  California    Amebiasis    145
# 5       2002  California    Amebiasis    279
# 6       2003  California    Amebiasis    403
# 7       2003  California    Amebiasis    127
# 8       2003  California    Amebiasis    261
# 9       2004  California    Amebiasis    359
# 10      2004  California    Amebiasis    101
# 11      2004  California    Amebiasis    247
# 12      2005  California    Amebiasis    365
# 13      2005  California    Amebiasis    103
# 14      2005  California    Amebiasis    255
# 15      2006  California    Amebiasis    377
# 16      2006  California    Amebiasis    110
# 17      2006  California    Amebiasis    257
# 18      2007  California    Amebiasis    433
# 19      2007  California    Amebiasis    142
# 20      2007  California    Amebiasis    286
# 21      2008  California    Amebiasis    436
# 22      2008  California    Amebiasis    147
# 23      2008  California    Amebiasis    287
# 24      2009  California    Amebiasis    398
# 25      2009  California    Amebiasis    112
# 26      2009  California    Amebiasis    285
# 27      2010  California    Amebiasis    406
# 28      2010  California    Amebiasis    108
# 29      2010  California    Amebiasis    297
# ...      ...         ...          ...    ...
# 141747  2005        Yuba  Yersiniosis      0
# 141748  2005        Yuba  Yersiniosis      0
# 141749  2005        Yuba  Yersiniosis      0
# 141750  2006        Yuba  Yersiniosis      0
# 141751  2006        Yuba  Yersiniosis      0
# 141752  2006        Yuba  Yersiniosis      0
# 141753  2007        Yuba  Yersiniosis      0
# 141754  2007        Yuba  Yersiniosis      0
# 141755  2007        Yuba  Yersiniosis      0
# 141756  2008        Yuba  Yersiniosis      0
# 141757  2008        Yuba  Yersiniosis      0
# 141758  2008        Yuba  Yersiniosis      0
# 141759  2009        Yuba  Yersiniosis      0
# 141760  2009        Yuba  Yersiniosis      0
# 141761  2009        Yuba  Yersiniosis      0
# 141762  2010        Yuba  Yersiniosis      0
# 141763  2010        Yuba  Yersiniosis      0
# 141764  2010        Yuba  Yersiniosis      0
# 141765  2011        Yuba  Yersiniosis      0
# 141766  2011        Yuba  Yersiniosis      0
# 141767  2011        Yuba  Yersiniosis      0
# 141768  2012        Yuba  Yersiniosis      0
# 141769  2012        Yuba  Yersiniosis      0
# 141770  2012        Yuba  Yersiniosis      0
# 141771  2013        Yuba  Yersiniosis      0
# 141772  2013        Yuba  Yersiniosis      0
# 141773  2013        Yuba  Yersiniosis      0
# 141774  2014        Yuba  Yersiniosis      0
# 141775  2014        Yuba  Yersiniosis      0
# 141776  2014        Yuba  Yersiniosis      0
#
# [141777 rows x 4 columns]

# %%
df1[(df1.Disease=='HIV') & (df1.County =='Butte')]
# Out:
#       Disease County  Year     Sex  Count  Population    Rate  CI.lower  \
# 61367     HIV  Butte  2001   Total     18      205730   8.749     5.185
# 61368     HIV  Butte  2001  Female      5      104697   4.776     1.551
# 61369     HIV  Butte  2001    Male     13      101033  12.867     6.851
# 61370     HIV  Butte  2002   Total     15      208154   7.206     4.033
# 61371     HIV  Butte  2002  Female      5      105823   4.725     1.534
# 61372     HIV  Butte  2002    Male     10      102331   9.772     4.686
# 61373     HIV  Butte  2003   Total     16      210623   7.597     4.342
# 61374     HIV  Butte  2003  Female      4      106998   3.738     1.019
# 61375     HIV  Butte  2003    Male     12      103625  11.580     5.984
# 61376     HIV  Butte  2004   Total     13      212212   6.126     3.262
# 61377     HIV  Butte  2004  Female      3      107746   2.784     0.574
# 61378     HIV  Butte  2004    Male     10      104466   9.573     4.590
# 61379     HIV  Butte  2005   Total      7      213698   3.276     1.317
# 61380     HIV  Butte  2005  Female      0      108417   0.000     0.000
# 61381     HIV  Butte  2005    Male      7      105281   6.649     2.673
# 61382     HIV  Butte  2006   Total      6      215684   2.782     1.021
# 61383     HIV  Butte  2006  Female      2      109338   1.829     0.222
# 61384     HIV  Butte  2006    Male      4      106346   3.761     1.025
# 61385     HIV  Butte  2007   Total     12      217115   5.527     2.856
# 61386     HIV  Butte  2007  Female      4      110027   3.635     0.991
# 61387     HIV  Butte  2007    Male      8      107088   7.470     3.225
# 61388     HIV  Butte  2008   Total     12      218485   5.492     2.838
# 61389     HIV  Butte  2008  Female      2      110685   1.807     0.219
# 61390     HIV  Butte  2008    Male     10      107800   9.276     4.448
# 61391     HIV  Butte  2009   Total      5      219287   2.280     0.740
# 61392     HIV  Butte  2009  Female      0      110967   0.000     0.000
# 61393     HIV  Butte  2009    Male      5      108320   4.616     1.499
# 61394     HIV  Butte  2010   Total      5      219971   2.273     0.738
# 61395     HIV  Butte  2010  Female      1      111086   0.900     0.023
# 61396     HIV  Butte  2010    Male      4      108885   3.674     1.001
# 61397     HIV  Butte  2011   Total      4      220434   1.815     0.494
# 61398     HIV  Butte  2011  Female      1      111240   0.899     0.023
# 61399     HIV  Butte  2011    Male      3      109194   2.747     0.567
# 61400     HIV  Butte  2012   Total      9      220980   4.073     1.862
# 61401     HIV  Butte  2012  Female      0      111415   0.000     0.000
# 61402     HIV  Butte  2012    Male      9      109565   8.214     3.756
# 61403     HIV  Butte  2013   Total      7      221416   3.161     1.271
# 61404     HIV  Butte  2013  Female      2      111548   1.793     0.217
# 61405     HIV  Butte  2013    Male      5      109868   4.551     1.478
# 61406     HIV  Butte  2014   Total      0      223905   0.000     0.000
# 61407     HIV  Butte  2014  Female      0      112637   0.000     0.000
# 61408     HIV  Butte  2014    Male      0      111268   0.000     0.000
#
#        CI.upper Unstable
# 61367    13.827        *
# 61368    11.145        *
# 61369    22.002        *
# 61370    11.885        *
# 61371    11.026        *
# 61372    17.971        *
# 61373    12.336        *
# 61374     9.571        *
# 61375    20.227        *
# 61376    10.475        *
# 61377     8.137        *
# 61378    17.603        *
# 61379     6.749        *
# 61380     3.402        -
# 61381    13.699        *
# 61382     6.055        *
# 61383     6.608        *
# 61384     9.630        *
# 61385     9.654        *
# 61386     9.308        *
# 61387    14.719        *
# 61388     9.594        *
# 61389     6.527        *
# 61390    17.059        *
# 61391     5.321        *
# 61392     3.324        -
# 61393    10.772        *
# 61394     5.304        *
# 61395     5.016        *
# 61396     9.406        *
# 61397     4.646        *
# 61398     5.009        *
# 61399     8.029        *
# 61400     7.731        *
# 61401     3.311        -
# 61402    15.593        *
# 61403     6.514        *
# 61404     6.477        *
# 61405    10.620        *
# 61406     1.648        -
# 61407     3.275        -
# 61408     3.315        -

# %%
aa = df1[(df1.Sex == 'Total') & (df1.Sex == '')].groupby(['Year', 'Disease']).sum()['Count']

# %%
aa

# %%
aaa = pd.DataFrame(aa[2014].sort_values(ascending = False))
aaa.columns = [2014]

# %%
aa[2005]
# Out:
# Disease
# Amebiasis                                                       730
# Anaplasmosis and Ehrlichiosis                                     8
# Babesiosis                                                        6
# Botulism, Foodborne                                               6
# Botulism, Other                                                   0
# Botulism, Wound                                                  54
# Brucellosis                                                      58
# Campylobacteriosis                                             9470
# Chlamydia                                                    258354
# Cholera                                                           2
# Ciguatera Fish Poisoning                                          2
# Coccidioidomycosis                                             5676
# Cryptosporidiosis                                               418
# Cysticercosis or Taeniasis                                      126
# Dengue                                                           22
# Diphtheria                                                        0
# E. coli O157                                                    374
# Early Syphilis                                                 5562
# Giardiasis                                                     4766
# Gonorrhea                                                     68198
# HIV                                                           10021
# Hantavirus Infection                                              0
# Hemolytic Uremic Syndrome                                        66
# Invasive Meningococcal Disease                                  378
# Legionellosis                                                   188
# Leprosy                                                          38
# Leptospirosis                                                    16
# Listeriosis                                                     254
# Lyme Disease                                                    194
# Malaria                                                         334
# Measles                                                           8
# Paralytic Shellfish Poisoning                                     2
# Pertussis                                                      6368
# Plague, human                                                     2
# Psittacosis                                                       4
# Q Fever                                                          34
# Rabies, human                                                     0
# Relapsing Fever                                                  10
# Salmonellosis                                                  9064
# Scombroid Fish Poisoning                                         52
# Shigellosis                                                    4438
# Spotted Fever Rickettsiosis                                       0
# Streptococcal Infection (cases in food and dairy workers)        36
# Tetanus                                                          14
# Toxic Shock Syndrome (Non-Streptococcal)                         12
# Trichinosis                                                       8
# Tuberculosis                                                   5800
# Tularemia                                                         8
# Typhoid Fever, case                                             110
# Typhus Fever                                                     20
# Vibrio Infection (non-Cholera)                                  198
# Yersiniosis                                                     220
# Name: Count, dtype: int64

# %%
aaa = pd.DataFrame()

# %%
kwargs = {"2007" : lambda x: aa[2005]}
aaa = aaa.assign(**kwargs)

# %%
aaa
# Out:
#                                                       y111    y121    2007
# Disease
# Amebiasis                                              730     730     730
# Anaplasmosis and Ehrlichiosis                            8       8       8
# Babesiosis                                               6       6       6
# Botulism, Foodborne                                      6       6       6
# Botulism, Other                                          0       0       0
# Botulism, Wound                                         54      54      54
# Brucellosis                                             58      58      58
# Campylobacteriosis                                    9470    9470    9470
# Chlamydia                                           258354  258354  258354
# Cholera                                                  2       2       2
# Ciguatera Fish Poisoning                                 2       2       2
# Coccidioidomycosis                                    5676    5676    5676
# Cryptosporidiosis                                      418     418     418
# Cysticercosis or Taeniasis                             126     126     126
# Dengue                                                  22      22      22
# Diphtheria                                               0       0       0
# E. coli O157                                           374     374     374
# Early Syphilis                                        5562    5562    5562
# Giardiasis                                            4766    4766    4766
# Gonorrhea                                            68198   68198   68198
# HIV                                                  10021   10021   10021
# Hantavirus Infection                                     0       0       0
# Hemolytic Uremic Syndrome                               66      66      66
# Invasive Meningococcal Disease                         378     378     378
# Legionellosis                                          188     188     188
# Leprosy                                                 38      38      38
# Leptospirosis                                           16      16      16
# Listeriosis                                            254     254     254
# Lyme Disease                                           194     194     194
# Malaria                                                334     334     334
# Measles                                                  8       8       8
# Paralytic Shellfish Poisoning                            2       2       2
# Pertussis                                             6368    6368    6368
# Plague, human                                            2       2       2
# Psittacosis                                              4       4       4
# Q Fever                                                 34      34      34
# Rabies, human                                            0       0       0
# Relapsing Fever                                         10      10      10
# Salmonellosis                                         9064    9064    9064
# Scombroid Fish Poisoning                                52      52      52
# Shigellosis                                           4438    4438    4438
# Spotted Fever Rickettsiosis                              0       0       0
# Streptococcal Infection (cases in food and dair...      36      36      36
# Tetanus                                                 14      14      14
# Toxic Shock Syndrome (Non-Streptococcal)                12      12      12
# Trichinosis                                              8       8       8
# Tuberculosis                                          5800    5800    5800
# Tularemia                                                8       8       8
# Typhoid Fever, case                                    110     110     110
# Typhus Fever                                            20      20      20
# Vibrio Infection (non-Cholera)                         198     198     198
# Yersiniosis                                            220     220     220

# %%
df1 = df1.assign(e=p.Series(np.random.randn(sLength)).values)

# %%
aaa
# Out:
#                                                       2014
# Disease
# Chlamydia                                           349114
# Gonorrhea                                            89948
# Pertussis                                            22436
# Campylobacteriosis                                   15838
# Early Syphilis                                       14382
# Salmonellosis                                        10722
# Coccidioidomycosis                                    4434
# Tuberculosis                                          4276
# Giardiasis                                            3646
# Shigellosis                                           3266
# E. coli Other STEC (non-O157)                          724
# Cryptosporidiosis                                      710
# Legionellosis                                          696
# E. coli O157                                           646
# Influenza Death (<65 years of age)                     636
# Amebiasis                                              576
# Vibrio Infection (non-Cholera)                         538
# Hepatitis A                                            284
# Dengue                                                 252
# Listeriosis                                            224
# Hepatitis B, Acute                                     216
# Malaria                                                184
# Measles                                                150
# Lyme Disease                                           146
# Hepatitis C, Acute                                     142
# Staphylococcus aureus Infection (cases resultin...     136
# Typhus Fever                                           132
# Typhoid Fever, case                                    130
# Invasive Meningococcal Disease                         114
# Yersiniosis                                            102
# ...                                                    ...
# Hepatitis E, acute infection                            62
# Scombroid Fish Poisoning                                44
# Brucellosis                                             40
# Creutzfeldt-Jakob Disease and other Transmissib...      38
# Cysticercosis or Taeniasis                              28
# Botulism, Wound                                         26
# Spotted Fever Rickettsiosis                             22
# Relapsing Fever                                         18
# Anaplasmosis and Ehrlichiosis                           14
# Leprosy                                                 12
# Leptospirosis                                           10
# Streptococcal Infection (cases in food and dair...       8
# Tetanus                                                  8
# Babesiosis                                               6
# Toxic Shock Syndrome (Non-Streptococcal)                 6
# Trichinosis                                              4
# Rubella                                                  4
# Cyclosporiasis                                           4
# Botulism, Other                                          2
# Hantavirus Infection                                     2
# Ciguatera Fish Poisoning                                 2
# Cholera                                                  0
# Rabies, human                                            0
# Psittacosis                                              0
# Plague, human                                            0
# Diphtheria                                               0
# Botulism, Foodborne                                      0
# Paralytic Shellfish Poisoning                            0
# HIV                                                      0
# Tularemia                                                0
#
# [65 rows x 1 columns]

# %%
pd.DataFrame(aa[2014].sort_values(ascending = False))
# Out:
#                                                      Count
# Disease
# Chlamydia                                           349114
# Gonorrhea                                            89948
# Pertussis                                            22436
# Campylobacteriosis                                   15838
# Early Syphilis                                       14382
# Salmonellosis                                        10722
# Coccidioidomycosis                                    4434
# Tuberculosis                                          4276
# Giardiasis                                            3646
# Shigellosis                                           3266
# E. coli Other STEC (non-O157)                          724
# Cryptosporidiosis                                      710
# Legionellosis                                          696
# E. coli O157                                           646
# Influenza Death (<65 years of age)                     636
# Amebiasis                                              576
# Vibrio Infection (non-Cholera)                         538
# Hepatitis A                                            284
# Dengue                                                 252
# Listeriosis                                            224
# Hepatitis B, Acute                                     216
# Malaria                                                184
# Measles                                                150
# Lyme Disease                                           146
# Hepatitis C, Acute                                     142
# Staphylococcus aureus Infection (cases resultin...     136
# Typhus Fever                                           132
# Typhoid Fever, case                                    130
# Invasive Meningococcal Disease                         114
# Yersiniosis                                            102
# ...                                                    ...
# Hepatitis E, acute infection                            62
# Scombroid Fish Poisoning                                44
# Brucellosis                                             40
# Creutzfeldt-Jakob Disease and other Transmissib...      38
# Cysticercosis or Taeniasis                              28
# Botulism, Wound                                         26
# Spotted Fever Rickettsiosis                             22
# Relapsing Fever                                         18
# Anaplasmosis and Ehrlichiosis                           14
# Leprosy                                                 12
# Leptospirosis                                           10
# Streptococcal Infection (cases in food and dair...       8
# Tetanus                                                  8
# Babesiosis                                               6
# Toxic Shock Syndrome (Non-Streptococcal)                 6
# Trichinosis                                              4
# Rubella                                                  4
# Cyclosporiasis                                           4
# Botulism, Other                                          2
# Hantavirus Infection                                     2
# Ciguatera Fish Poisoning                                 2
# Cholera                                                  0
# Rabies, human                                            0
# Psittacosis                                              0
# Plague, human                                            0
# Diphtheria                                               0
# Botulism, Foodborne                                      0
# Paralytic Shellfish Poisoning                            0
# HIV                                                      0
# Tularemia                                                0
#
# [65 rows x 1 columns]

# %%
[[i, aa[i].sort_values(ascending = False)[:15]] for i in [2010,2011]]
# Out:
# [[2010, Disease
#   Chlamydia             310706
#   Gonorrhea              53688
#   Pertussis              18318
#   Campylobacteriosis     13302
#   Salmonellosis          10102
#   HIV                     9841
#   Coccidioidomycosis      8862
#   Early Syphilis          7750
#   Tuberculosis            4650
#   Giardiasis              3554
#   Shigellosis             2172
#   Amebiasis                812
#   Cryptosporidiosis        742
#   E. coli O157             442
#   Legionellosis            438
#   Name: Count, dtype: int64], [2011, Disease
#   Chlamydia             329650
#   Gonorrhea              54966
#   Campylobacteriosis     13522
#   Coccidioidomycosis     10434
#   HIV                     9520
#   Early Syphilis          8996
#   Salmonellosis           8076
#   Pertussis               6034
#   Tuberculosis            4646
#   Giardiasis              3452
#   Shigellosis             1898
#   Amebiasis                730
#   Cryptosporidiosis        704
#   E. coli O157             498
#   Legionellosis            498
#   Name: Count, dtype: int64]]

# %%
pd.DataFrame([[i, aa[i].sort_values(ascending = False)[:15]] for i in [2010,2011]])
# Out:
#       0                                                  1
# 0  2010  Disease
# Chlamydia             310706
# Gonorrhea...
# 1  2011  Disease
# Chlamydia             329650
# Gonorrhea...

# %%
range(len(tmp[yr].sort_values(ascending = False)[:15]))

# %%
pd.DataFrame(aa[2004]).append(aaa)
# Out:
#                                    Count     0
# Amebiasis                          718.0   NaN
# Anaplasmosis and Ehrlichiosis        4.0   NaN
# Babesiosis                           0.0   NaN
# Botulism, Foodborne                 10.0   NaN
# Botulism, Other                      0.0   NaN
# Botulism, Wound                     36.0   NaN
# Brucellosis                         52.0   NaN
# Campylobacteriosis               10164.0   NaN
# Chlamydia                       246878.0   NaN
# Cholera                              2.0   NaN
# Ciguatera Fish Poisoning             6.0   NaN
# Coccidioidomycosis                5074.0   NaN
# Cryptosporidiosis                  604.0   NaN
# Cysticercosis or Taeniasis         116.0   NaN
# Dengue                               2.0   NaN
# Diphtheria                           0.0   NaN
# E. coli O157                       462.0   NaN
# Early Syphilis                    4504.0   NaN
# Giardiasis                        4446.0   NaN
# Gonorrhea                        60962.0   NaN
# HIV                              10344.0   NaN
# Hantavirus Infection                 6.0   NaN
# Hemolytic Uremic Syndrome           76.0   NaN
# Invasive Meningococcal Disease     398.0   NaN
# Legionellosis                      128.0   NaN
# Leprosy                             44.0   NaN
# Leptospirosis                        2.0   NaN
# Listeriosis                        246.0   NaN
# Lyme Disease                       102.0   NaN
# Malaria                            316.0   NaN
# ...                                  ...   ...
# 22                                   NaN  22.0
# 23                                   NaN  23.0
# 24                                   NaN  24.0
# 25                                   NaN  25.0
# 26                                   NaN  26.0
# 27                                   NaN  27.0
# 28                                   NaN  28.0
# 29                                   NaN  29.0
# 30                                   NaN  30.0
# 31                                   NaN  31.0
# 32                                   NaN  32.0
# 33                                   NaN  33.0
# 34                                   NaN  34.0
# 35                                   NaN  35.0
# 36                                   NaN  36.0
# 37                                   NaN  37.0
# 38                                   NaN  38.0
# 39                                   NaN  39.0
# 40                                   NaN  40.0
# 41                                   NaN  41.0
# 42                                   NaN  42.0
# 43                                   NaN  43.0
# 44                                   NaN  44.0
# 45                                   NaN  45.0
# 46                                   NaN  46.0
# 47                                   NaN  47.0
# 48                                   NaN  48.0
# 49                                   NaN  49.0
# 50                                   NaN  50.0
# 51                                   NaN  51.0
#
# [104 rows x 2 columns]

# %%
pd.DataFrame([aa[2004],aaa])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-d027cc24289b> in <module>()
# ----> 1 pd.DataFrame([aa[2004],aaa])
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     312                     if is_named_tuple(data[0]) and columns is None:
#     313                         columns = data[0]._fields
# --> 314                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     315                     columns = _ensure_index(columns)
#     316
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    5720         return _list_of_series_to_arrays(data, columns,
#    5721                                          coerce_float=coerce_float,
# -> 5722                                          dtype=dtype)
#    5723     elif isinstance(data[0], Categorical):
#    5724         if columns is None:
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _list_of_series_to_arrays(data, columns, coerce_float, dtype)
#    5800     if columns is None:
#    5801         columns = _get_combined_index([
# -> 5802             s.index for s in data if getattr(s, 'index', None) is not None
#    5803         ])
#    5804
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/api.py in _get_combined_index(indexes, intersect)
#      41             index = index.intersection(other)
#      42         return index
# ---> 43     union = _union_indexes(indexes)
#      44     return _ensure_index(union)
#      45
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/api.py in _union_indexes(indexes)
#      75         else:
#      76             for other in indexes[1:]:
# ---> 77                 result = result.union(other)
#      78             return result
#      79     elif kind == 'array':
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in union(self, other)
#    2098
#    2099         """
# -> 2100         self._assert_can_do_setop(other)
#    2101         other = _ensure_index(other)
#    2102
#
# /home/franchb/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _assert_can_do_setop(self, other)
#    1028     def _assert_can_do_setop(self, other):
#    1029         if not is_list_like(other):
# -> 1030             raise TypeError('Input must be Index or array-like')
#    1031         return True
#    1032
#
# TypeError: Input must be Index or array-like

# %%
aa[2004][:10]
# Out:
# Disease
# Amebiasis                           718
# Anaplasmosis and Ehrlichiosis         4
# Babesiosis                            0
# Botulism, Foodborne                  10
# Botulism, Other                       0
# Botulism, Wound                      36
# Brucellosis                          52
# Campylobacteriosis                10164
# Chlamydia                        246878
# Cholera                               2
# Name: Count, dtype: int64

# %%
pd.DataFrame(aa[2004]).reset_index()
# Out:
#                                               Disease   Count
# 0                                           Amebiasis     718
# 1                       Anaplasmosis and Ehrlichiosis       4
# 2                                          Babesiosis       0
# 3                                 Botulism, Foodborne      10
# 4                                     Botulism, Other       0
# 5                                     Botulism, Wound      36
# 6                                         Brucellosis      52
# 7                                  Campylobacteriosis   10164
# 8                                           Chlamydia  246878
# 9                                             Cholera       2
# 10                           Ciguatera Fish Poisoning       6
# 11                                 Coccidioidomycosis    5074
# 12                                  Cryptosporidiosis     604
# 13                         Cysticercosis or Taeniasis     116
# 14                                             Dengue       2
# 15                                         Diphtheria       0
# 16                                       E. coli O157     462
# 17                                     Early Syphilis    4504
# 18                                         Giardiasis    4446
# 19                                          Gonorrhea   60962
# 20                                                HIV   10344
# 21                               Hantavirus Infection       6
# 22                          Hemolytic Uremic Syndrome      76
# 23                     Invasive Meningococcal Disease     398
# 24                                      Legionellosis     128
# 25                                            Leprosy      44
# 26                                      Leptospirosis       2
# 27                                        Listeriosis     246
# 28                                       Lyme Disease     102
# 29                                            Malaria     316
# 30                                            Measles      12
# 31                      Paralytic Shellfish Poisoning       0
# 32                                          Pertussis    2260
# 33                                      Plague, human       0
# 34                                        Psittacosis       2
# 35                                            Q Fever      26
# 36                                      Rabies, human       2
# 37                                    Relapsing Fever      14
# 38                                      Salmonellosis    8550
# 39                           Scombroid Fish Poisoning      60
# 40                                        Shigellosis    3700
# 41                        Spotted Fever Rickettsiosis       2
# 42  Streptococcal Infection (cases in food and dai...      20
# 43                                            Tetanus      12
# 44           Toxic Shock Syndrome (Non-Streptococcal)       8
# 45                                        Trichinosis       2
# 46                                       Tuberculosis    5984
# 47                                          Tularemia       4
# 48                                Typhoid Fever, case     140
# 49                                       Typhus Fever      22
# 50                     Vibrio Infection (non-Cholera)     292
# 51                                        Yersiniosis     178

# %%
df1[df1.Sex == 'Total'].groupby(['Year', 'Disease']).sum()['Count']
# Out:
# Year  Disease
# 2001  Amebiasis                                                              228.4
#       Anaplasmosis and Ehrlichiosis                                            0.4
#       Babesiosis                                                               0.0
#       Botulism, Foodborne                                                      1.6
#       Botulism, Other                                                          0.0
#       Botulism, Wound                                                          8.0
#       Brucellosis                                                             14.4
#       Campylobacteriosis                                                    2244.0
#       Chlamydia                                                            40636.0
#       Cholera                                                                  0.0
#       Ciguatera Fish Poisoning                                                 1.2
#       Coccidioidomycosis                                                     596.0
#       Cryptosporidiosis                                                       94.4
#       Cysticercosis or Taeniasis                                              35.2
#       Dengue                                                                  10.4
#       Diphtheria                                                               0.0
#       E. coli O157                                                           102.4
#       Early Syphilis                                                         383.2
#       Giardiasis                                                            1186.4
#       Gonorrhea                                                             9314.0
#       HIV                                                                   2266.0
#       Hantavirus Infection                                                     0.0
#       Hemolytic Uremic Syndrome                                               16.8
#       Invasive Meningococcal Disease                                         123.4
#       Legionellosis                                                           22.8
#       Leprosy                                                                  7.6
#       Leptospirosis                                                            0.8
#       Listeriosis                                                             47.2
#       Lyme Disease                                                            36.0
#       Malaria                                                                 70.8
#                                                                             ...
# 2014  Listeriosis                                                             44.8
#       Lyme Disease                                                            29.2
#       Malaria                                                                 36.8
#       Measles                                                                 30.0
#       Mumps                                                                   14.8
#       Paralytic Shellfish Poisoning                                            0.0
#       Pertussis                                                             4487.2
#       Plague, human                                                            0.0
#       Psittacosis                                                              0.0
#       Q Fever                                                                 14.0
#       Rabies, human                                                            0.0
#       Relapsing Fever                                                          3.6
#       Rubella                                                                  0.8
#       Salmonellosis                                                         2144.4
#       Scombroid Fish Poisoning                                                 8.8
#       Shiga Toxin Positive Feces (without culture confirmation)               19.2
#       Shigellosis                                                            653.2
#       Spotted Fever Rickettsiosis                                              4.4
#       Staphylococcus aureus Infection (cases resulting in death or ICU)       27.2
#       Streptococcal Infection (cases in food and dairy workers)                1.6
#       Tetanus                                                                  1.6
#       Toxic Shock Syndrome (Non-Streptococcal)                                 1.2
#       Trichinosis                                                              0.8
#       Tuberculosis                                                           855.2
#       Tularemia                                                                0.0
#       Typhoid Fever, case                                                     26.0
#       Typhus Fever                                                            26.4
#       Varicella Hospitalizations                                              16.4
#       Vibrio Infection (non-Cholera)                                         107.6
#       Yersiniosis                                                             20.4
# Name: Count, Length: 801, dtype: float64

# %%
df_populations = df1

# %%
#1. List of TOP Diseases

# %%
import numpy as np

# %%
['T'+str(i) for i in np.arange(1,11,1)]
# Out:
# ['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10', 'dd']

# %%
df1.Year.unique()[:-1]
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013])

# %%
df_populations = pd.DataFrame(columns = ['Year']+['T'+str(i) for i in np.arange(1,11,1)]).set_index('Year')

# %%
def get_population(year, county, sex = 'Total'):
    """
    Returns population in given county at given year with given sex.
    """    
    return df1[(df1.Year == year) & (df1.Sex == sex)\
              & (df1.Disease == 'HIV')\
              & (df1.County == county)]['Population'].iloc[0]

# %%
def get_rate(year, county, sex = 'Total')

# %%
get_population(2005, 'Sierra', sex = 'Total')
# Out:
# 3430

# %%
df1[(df1.Year == 2002) & (df1.Disease == 'HIV') & (df1.County == 'Sierra')]['Population']
# Out:
# 52102    3564
# 52103    1759
# 52104    1805
# Name: Population, dtype: int64

# %%
df_populations
# Out:
# Empty DataFrame
# Columns: [T1, T2, T3, T4, T5, T6, T7, T8, T9, T10]
# Index: []

# %%
df4 = df1[['Year', 'County', 'Disease', 'Count']]

# %%
df1[df1.Sex == 'Total' & df1.County ==]['Population']
# Out:
# 0         34514777
# 3         34940334
# 6         35390986
# 9         35754827
# 12        35987637
# 15        36248870
# 18        36554575
# 21        36858270
# 24        37079253
# 27        37311439
# 30        37572186
# 33        37869573
# 36        38166117
# 39        38501494
# 42         1466038
# 45         1468943
# 48         1467663
# 51         1466017
# 54         1460358
# 57         1465322
# 60         1476892
# 63         1492275
# 66         1504325
# 69         1513734
# 72         1526738
# 75         1539660
# 78         1564017
# 81         1584507
# 84            1237
# 87            1248
#             ...
# 141687      839270
# 141690      844259
# 141693      175102
# 141696      179271
# 141699      182331
# 141702      185707
# 141705      187354
# 141708      190809
# 141711      194854
# 141714      197589
# 141717      199697
# 141720      201328
# 141723      202616
# 141726      204974
# 141729      206136
# 141732      207212
# 141735       61426
# 141738       62738
# 141741       63962
# 141744       65249
# 141747       67712
# 141750       69218
# 141753       70221
# 141756       71422
# 141759       71796
# 141762       72336
# 141765       72623
# 141768       72915
# 141771       72994
# 141774       73425
# Name: Population, Length: 47259, dtype: int64
