# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv?

# %%
df = pd.read_csv('AIDSinfo_2015_en.csv', dtype={'Indicator': str,\
                                                'Unit': str,\
                                                'Subgroup': str,\
                                                'Area': str,\
                                                'Area ID': str,\
                                                'Time Period': int,\
                                                'Source': str,\
                                                'Data Value': float,\
                                                'Footnotes': str})

# %%
df.columns
# Out:
# Index(['Indicator', 'Unit', 'Subgroup', 'Area', 'Area ID', 'Time Period',
#        'Source', 'Data Value', 'Footnotes'],
#       dtype='object')

# %%
df.head()
# Out:
#                                            Indicator     Unit Subgroup  \
# 0  External economic support to the poorest house...  Percent    Total
# 1  External economic support to the poorest house...  Percent    Total
# 2  External economic support to the poorest house...  Percent    Total
# 3  External economic support to the poorest house...  Percent    Total
# 4  External economic support to the poorest house...  Percent    Total
#
#                  Area Area ID  Time Period         Source  Data Value  \
# 0               Chile     CHL         2014  UNAIDS_GARPR_      75.400
# 1  Dominican Republic     DOM         2014  UNAIDS_GARPR_      29.800
# 2             Ecuador     ECU         2014  UNAIDS_GARPR_       0.000
# 3            Honduras     HND         2014  UNAIDS_GARPR_      37.000
# 4           Indonesia     IDN         2014  UNAIDS_GARPR_      86.504
#
#                                            Footnotes
# 0                                 Source: CASEN 2013
# ...

# %%
sorted(df["Area ID"].unique())
# Out:
# ['03M49WLD',
#  'ABW',
#  'AFG',
#  'AGO',
#  'AIA',
#  'ALB',
#  'AND',
#  'ARE',
#  'ARG',
#  'ARM',
#  'ARM001',
#  'ARM002',
#  'ARM003',
#  'ARM005',
#  'ARM008',
#  'ARM009',
#  'ARM013',
#  'ARM015',
#  'ARM016',
#  'ARM017',
#  'ARM018',
#  'ASM',
#  'ATG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BEN_01',
#  'BEN_02',
#  'BEN_03',
#  'BEN_04',
#  'BEN_05',
#  'BEN_06',
#  'BEN_07',
#  'BEN_08',
#  'BEN_09',
#  'BEN_10',
#  'BEN_11',
#  'BEN_12',
#  'BFA',
#  'BFA001',
#  'BFA002',
#  'BFA003',
#  'BFA004',
#  'BFA005',
#  'BFA006',
#  'BFA007',
#  'BFA008',
#  'BFA009',
#  'BFA010',
#  'BFA011',
#  'BFA012',
#  'BFA013',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BHS',
#  'BIH',
#  'BLR',
#  'BLZ',
#  'BMU',
#  'BOL',
#  'BOL001',
#  'BOL002',
#  'BOL003',
#  'BOL004',
#  'BOL005',
#  'BOL006',
#  'BOL007',
#  'BOL008',
#  'BOL009',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BTN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CIV001',
# ...

# %%
df[df["Area ID"] == 'RUS'].head()
# Out:
#                                                 Indicator     Unit  Subgroup  \
# 604039  Proportion of people living with HIV receiving...  Percent     Total
# 604857  HIV-specific restrictions on entry, stay or re...   Yes/No  Reported
# 605435     Expenditure on collaborative TB/HIV activities      US$     Total
# 605436     Expenditure on collaborative TB/HIV activities      US$     Total
# 605437     Expenditure on collaborative TB/HIV activities      US$     Total
#
#                       Area Area ID  Time Period         Source    Data Value  \
# 604039  Russian Federation     RUS         2014      WHO_Data_  3.799990e+01
# 604857  Russian Federation     RUS         2015  UNAIDS_GARPR_  3.300000e+01
# 605435  Russian Federation     RUS         2004      WHO_Data_  6.600000e+05
# 605436  Russian Federation     RUS         2005      WHO_Data_  2.000000e+05
# 605437  Russian Federation     RUS         2006      WHO_Data_  2.000000e+06
#
#        Footnotes
# 604039       NaN
# ...

# %%
len(df[df["Area ID"] == 'RUS'])
# Out:
# 350

# %%
df[df["Area ID"] == 'RUS'].Indicator.unique()
# Out:
# array(['Proportion of people living with HIV receiving TB preventive therapy',
#        'HIV-specific restrictions on entry, stay or residence',
#        'Expenditure on collaborative TB/HIV activities',
#        'Number of TB patients living with HIV receiving ART',
#        'Co-management of tuberculosis and HIV treatment',
#        'People living with HIV screened for TB',
#        'HIV testing among TB patients',
#        'Number of people living with HIV receiving tuberculosis (TB) preventive therapy',
#        'TB patients living with HIV receiving CPT',
#        'Incident TB cases in people living with HIV',
#        'TB-related deaths among people living with HIV',
#        'HIV in new TB cases', 'Total TB expenditure',
#        'TB patients tested positive for HIV',
#        'Total new and relapse TB cases',
#        'Proportion of registered new and relapse TB patients with documented HIV status',
# ...

# %%
df[(df["Area ID"] == 'RUS') & (df["Indicator"] == "People receiving antiretroviral therapy")]
# Out:
#                                       Indicator    Unit Subgroup  \
# 672877  People receiving antiretroviral therapy  Number    Total
#
#                       Area Area ID  Time Period         Source  Data Value  \
# 672877  Russian Federation     RUS         2015  UNAIDS_GARPR_    230022.0
#
#        Footnotes
# 672877       NaN

# %%
df[(df["Indicator"] == "People receiving antiretroviral therapy")]
# Out:
#                                       Indicator    Unit  \
# 441     People receiving antiretroviral therapy  Number
# 442     People receiving antiretroviral therapy  Number
# 527     People receiving antiretroviral therapy  Number
# 528     People receiving antiretroviral therapy  Number
# 529     People receiving antiretroviral therapy  Number
# 530     People receiving antiretroviral therapy  Number
# 531     People receiving antiretroviral therapy  Number
# 4332    People receiving antiretroviral therapy  Number
# 4333    People receiving antiretroviral therapy  Number
# 4334    People receiving antiretroviral therapy  Number
# 4335    People receiving antiretroviral therapy  Number
# 4336    People receiving antiretroviral therapy  Number
# 4337    People receiving antiretroviral therapy  Number
# 4338    People receiving antiretroviral therapy  Number
# 4339    People receiving antiretroviral therapy  Number
# 4340    People receiving antiretroviral therapy  Number
# ...

# %%
len(df[(df["Indicator"] == "People receiving antiretroviral therapy")])
# Out:
# 7573

# %%
df[(df["Indicator"] == "People receiving antiretroviral therapy")].Area.unique()
# Out:
# array(['All countries', 'Afghanistan', 'Alibori', 'Atacora', 'Atlantique',
#        'Borgou', 'Collines', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Australia', 'Azerbaijan', 'Bahamas', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belize', 'Benin', 'Bolivia (Plurinational State of)',
#        'Botswana', 'Brazil', 'Burkina Faso', 'Burundi', 'Cambodia',
#        'Cameroon', 'Cape Verde', 'Central African Republic', 'Chad',
#        'Chile', 'Costa Rica', "Côte d'Ivoire", 'Cuba',
#        'Democratic Republic of the Congo', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Gabon', 'Gambia', 'Georgia',
#        'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Jamaica',
#        'Kazakhstan', 'Kenya', 'Kyrgyzstan', 'Latvia', 'Lebanon', 'Lesotho',
#        'North Eastern', 'Nyanza', 'Rift Valley', 'Western',
# ...
